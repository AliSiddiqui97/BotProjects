# %%
from selenium import webdriver
from time import sleep
from selenium.webdriver.common.keys import Keys

driver = webdriver.Firefox(executable_path='./geckodriver')
driver.get("https://messages.google.com/web/authentication")
sleep(2)

# %%
message = " موٹر سائیکل بیچنا چاہتے ہیں توebike. pk پر video کے ساتھ اپنا Ad لگائیں اور bike بیچ دیں اور اگر bike خریدنا چاہتے ہیں توhttps://www.ebike.pk/  وزٹ کریں۔"

# %%
newlist = [
    '0345 2382228',
"+92 316 7724488",
"+92 315 9228405",
"+92 342 8768198",
"+92 313 5898899",
"+92 313 5898899",
"+92 316 8831543",
"+92 312 9809789",
"+92 323 9809505",
"+92 333 9628804",
"+92 311 7466171",
"+92 311 1867367",
"+92 349 1904209",
"+92 316 1838279",
"+92 311 9305208",
"+92 348 1919408",
"+92 313 9087834",
"+92 300 0531010",
"+92 321 4724224",
"+92 302 4354122",
"+92 302 4354122",
"+92 302 4354122",
"+92 344 3604068",
"+92 318 5010788",
"+92 311 7785584",
"+92 340 5219173",
"+92 306 9445962",
"+92 312 9803000",
"+92 300 5683888",
"+92 300 5683888",
"+92 314 5052575",
"+92 342 2916940",
"+92 311 9974174",
"+92 342 8768198",
"+92 300 5683888",
"+92 343 9213996",
"+92 345 7931459",
"+92 314 9764422",
"+92 345 7931459",
"+92 334 2000355",
"+92 334 2000355",
"+92 313 3299080",
"+92 312 1511234",
"+92 300 5683888",
"+92 340 4519114",
"+92 340 5621984",
"+92 316 9256568",
"+92 316 9849537",
"+92 316 9256568",
"+92 311 9040819",
"+92 305 9227279",
"+92 316 5557755",
"+92 314 5855444",
"+92 307 5954023",
"+92 333 8648346",
"+92 311 9979177",
"+92 331 9404302",
"+92 312 6325757"
]
len(newlist)
# Out:
# 58

# %%
i=0
while i<len(newlist):
    driver.find_element_by_xpath("/html/body/mw-app/div/main/mw-main-container/div[1]/mw-main-nav/div/mw-fab-link/a/span").click()
    sleep(3)

    driver.find_element_by_class_name("input").send_keys(newlist[i])
    sleep(2)
    driver.find_element_by_xpath("/html/body/mw-app/div/main/mw-main-container/div[1]/mw-new-conversation-container/div/mw-contact-selector-button/button").click()
    sleep(7)
    driver.find_element_by_xpath('/html/body/mw-app/div/main/mw-main-container/div[1]/mw-conversation-container/div/div/mws-message-compose/div/div[2]/div/mws-autosize-textarea/textarea').send_keys(message)
    sleep(4)
    driver.find_element_by_xpath("/html/body/mw-app/div/main/mw-main-container/div[1]/mw-conversation-container/div/div/mws-message-compose/div/mws-message-send-button/button").click()
    sleep(2)
    print((i))
    print(newlist[i])
    i+=1
# Out:
# 0
# 0345 2382228
# 1
# +92 316 7724488
# 2
# +92 315 9228405
# 3
# +92 342 8768198
# 4
# +92 313 5898899
# 5
# +92 313 5898899
# 6
# +92 316 8831543
# 7
# +92 312 9809789
# 8
# +92 323 9809505
# 9
# +92 333 9628804
# 10
# +92 311 7466171
# 11
# +92 311 1867367
# 12
# +92 349 1904209
# 13
# +92 316 1838279
# 14
# +92 311 9305208
# 15
# +92 348 1919408
# 16
# +92 313 9087834
# 17
# +92 300 0531010
# 18
# +92 321 4724224
# 19
# +92 302 4354122
# 20
# +92 302 4354122
# 21
# +92 302 4354122
# 22
# +92 344 3604068
# 23
# +92 318 5010788
# 24
# +92 311 7785584
# 25
# +92 340 5219173
# 26
# +92 306 9445962
# 27
# +92 312 9803000
# 28
# +92 300 5683888
# 29
# +92 300 5683888
# 30
# +92 314 5052575
# 31
# +92 342 2916940
# 32
# +92 311 9974174
# 33
# +92 342 8768198
# 34
# +92 300 5683888
# 35
# +92 343 9213996
# 36
# +92 345 7931459
# 37
# +92 314 9764422
# 38
# +92 345 7931459
# 39
# +92 334 2000355
# 40
# +92 334 2000355
# 41
# +92 313 3299080
# 42
# +92 312 1511234
# 43
# +92 300 5683888
# ...
